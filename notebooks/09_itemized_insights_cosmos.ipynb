# %% [markdown]
# # Long-Term Memory Prioritization Demo (CosmosDB)
#
# ## 🎯 Notebook Overview
#
# This notebook simulates a **6-month financial advisor relationship** where an AI system learns and evolves its understanding of a client using bounded-capacity memory with Azure CosmosDB backend. The system demonstrates how insights compete for limited storage slots and how memory naturally prioritizes what matters most.
#
# ### Core Concepts Demonstrated
# - **Recency Effect**: New insights get a temporary priority boost that decays over time (Ebbinghaus forgetting curve)
# - **Frequency Reinforcement**: Insights cited in multiple sessions gain strength through increased access counts
# - **Bounded Capacity**: Only the top 5 most important/recent/frequently-used insights survive; weaker ones are deleted
# - **Temporal Awareness**: Insights are only fetched from sessions that occurred before the current session (prevents future-content leakage)
# - **Enterprise Storage**: Uses Azure CosmosDB for production-grade distributed storage with vector search capabilities
#
# ### What Happens in the Demo
# 1. **6 Simulated Sessions**: Alex's financial journey from risk-averse beginner ($120k income) → confident investor (promoted to $150k)
# 2. **Insight Extraction**: After each session, LLM extracts 0-5 new insights about Alex's preferences, goals, and behavior patterns
# 3. **Memory Competition**: New insights are ranked by retention score (recency + frequency + importance)
# 4. **Automatic Pruning**: When insights exceed 5, the lowest-scoring ones are automatically deleted
# 5. **Evolution Tracking**: See how insights rise/fall in priority across the 6-month timeline
#
# ### Environment Prerequisites
# - `AZURE_OPENAI_ENDPOINT` - Azure OpenAI API endpoint
# - `AZURE_OPENAI_API_KEY` - API key for Azure OpenAI
# - `COSMOS_ENDPOINT` and `COSMOS_KEY` - Azure CosmosDB connection (or Azure AD credentials)
# - `AZURE_OPENAI_PROCESSING_MODEL` - Model to use for insight extraction (default: gpt-4o-mini)

# %% [markdown]
# ## Cell 1: Environment Setup & Configuration
#
# - Resolves project root directory and loads `.env` variables
# - Imports Azure OpenAI, CosmosDB, and memory system dependencies
# - Configures bounded memory constants (MAX_INSIGHTS=5, USER_ID)
# - Initializes Azure OpenAI client for LLM calls
# - Creates TIMELINE data with 6 months of financial coaching sessions (Alex's journey)

# %%
import asyncio
import os
import sys
from pathlib import Path
from datetime import datetime
from typing import Dict, List

from dotenv import load_dotenv

# Resolve project root by walking up until we find the .env or pyproject.toml
cwd = Path.cwd().resolve()
BASE_DIR = cwd
for parent in [cwd] + list(cwd.parents):
    if (parent / '.env').exists() or (parent / 'pyproject.toml').exists():
        BASE_DIR = parent
        break

if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))

load_dotenv(BASE_DIR / '.env', override=True)

from openai import AzureOpenAI
from memory.db.cosmos_backend import CosmosDBDatabase
from memory.db.base import ContainerType
from memory.providers.embedding import OpenAIEmbeddingProvider
from memory.core.reflection import Reflection, ReflectionConfig
from memory.core.insight_items import (
    LongTermInsightItem,
    InsightIdGenerator,
    rank_insights,
    calculate_retention_score,
    SessionAnalysisWithCitations,
    build_context_with_ids,
)

USER_ID = 'memory_priority_demo_cosmos'
MAX_INSIGHTS = 5

client = AzureOpenAI(
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT'],
    api_key=os.environ.get('AZURE_OPENAI_API_KEY'),
    api_version='2024-10-21',
)

TIMELINE = [
    {
        'session_id': 'month-1',
        'simulated_date': datetime(2025, 1, 15),
        'title': 'Month 1: Initial Consultation',
        'summary': 'Alex is 28, software engineer earning $120k. Wants to start investing. Very risk-averse due to parents 2008 losses. Prefers bonds and savings. Has $10,000 emergency fund. Interested in Roth IRA.',
        'turns': [
            ('user', "I'm Alex, 28, making $120k. I want to start investing but I'm scared of losing money."),
            ('assistant', "That's understandable. Let's start with your risk tolerance and goals."),
            ('user', "My parents lost a lot in 2008. I want safe investments - bonds, savings accounts."),
            ('assistant', "With your fear of losses, we can start conservatively. You mentioned a Roth IRA?"),
            ('user', "Yes, I want to learn about Roth IRAs. I have $10k saved for emergencies."),
        ],
    },
    {
        'session_id': 'month-2',
        'simulated_date': datetime(2025, 2, 20),
        'title': 'Month 2: Roth IRA Setup',
        'summary': 'Alex opened a Roth IRA last month and asks about contribution limits. Still conservative with money market allocation. Mentions saving for sisters wedding.',
        'turns': [
            ('user', "I opened the Roth IRA! How much can I contribute this year?"),
            ('assistant', "Great! The 2025 limit is $7,000. Given your conservative preference, what did you choose?"),
            ('user', "I put it in a money market fund. I know it's low return but I can't handle volatility."),
            ('assistant', "That's fine to start. Any other financial goals coming up?"),
            ('user', "My sister's wedding is in April. I need to save about $2,000 for travel and gift."),
        ],
    },
    {
        'session_id': 'month-3',
        'simulated_date': datetime(2025, 3, 25),
        'title': 'Month 3: Tax Season Questions',
        'summary': 'Alex asks tax implications of Roth contributions and plans to max out the Roth IRA. Risk profile still conservative.',
        'turns': [
            ('user', "Quick tax question - do my Roth IRA contributions reduce my taxable income?"),
            ('assistant', "No, Roth contributions are post-tax. But withdrawals in retirement are tax-free."),
            ('user', "I think I want to max out my Roth this year."),
            ('assistant', "Good plan. Still comfortable with money market holdings?"),
            ('user', "Yes, not ready for stocks yet. Maybe next year."),
        ],
    },
    {
        'session_id': 'month-4',
        'simulated_date': datetime(2025, 5, 10),
        'title': 'Month 4: Post-Wedding, Promotion News',
        'summary': 'Wedding complete. Alex promoted to $150k and starts reconsidering risk tolerance. Asks about target-date funds.',
        'turns': [
            ('user', "Big news! Wedding was great, and I just got promoted to $150k!"),
            ('assistant', "Congratulations! How are you feeling about finances now?"),
            ('user', "More confident. Maybe I can handle some risk."),
            ('assistant', "Would you like to explore middle-ground options?"),
            ('user', "Yes, target-date funds seem balanced."),
        ],
    },
    {
        'session_id': 'month-5',
        'simulated_date': datetime(2025, 6, 15),
        'title': 'Month 5: Risk Tolerance Shift',
        'summary': 'Alex moves Roth IRA to target-date 2060 fund and starts taxable account planning for home down payment.',
        'turns': [
            ('user', "I moved my Roth to a 2060 target-date fund."),
            ('assistant', "Great step. How do you feel about it?"),
            ('user', "Good. Now I want a taxable account too."),
            ('assistant', "Any goal for the taxable account?"),
            ('user', "House down payment in 3-4 years."),
        ],
    },
    {
        'session_id': 'month-6',
        'simulated_date': datetime(2025, 7, 20),
        'title': 'Month 6: Current State & Planning',
        'summary': 'Alex keeps house fund conservative while becoming aggressive for long-term retirement and considers higher 401k contributions.',
        'turns': [
            ('user', "I started the house fund with $5,000 and kept it conservative."),
            ('assistant', "Good time-horizon matching. How is your 401k?"),
            ('user', "Should I increase 401k contributions now?"),
            ('assistant', "At $150k, maxing 401k is ideal if cash flow allows."),
            ('user', "I'll do that."),
        ],
    },
]

print(f'Base directory: {BASE_DIR}')
print('Setup complete.')
# Out:
# Base directory: C:\LabFiles\agent-memory
# Setup complete.

# %% [markdown]
# ## Cell 2: Helper Functions for Insight Management
#
# - `print_section()`: Formats and displays section headers with decorative borders
# - `print_insight_table()`: Displays ranked insights with scores, access counts, age, and importance
# - `get_insight_items()`: Retrieves stored insight items from CosmosDB database
# - `cleanup_demo_data()`: Removes all demo insights before/after runs to keep DB clean
# - `prune_insights()`: Enforces bounded memory by removing weakest insights when capacity exceeded
# - `run_session_with_simulated_time()`: Orchestrates session analysis via LLM to extract and cite insights

# %%
async def get_insight_items(db: CosmosDBDatabase, user_id: str, cutoff_date: datetime = None) -> List[LongTermInsightItem]:
    """Get active long-term insight items for a user (excluding deleted/cleanup failures).
    
    Args:
        db: Database client
        user_id: User identifier
        cutoff_date: Optional date to only include insights created before this date.
                     Helps prevent future insights from appearing in early sessions.
    """
    # Note: There's a known issue where CosmosDB delete() returns False without deleting documents.
    # As a workaround, we filter for is_deleted=False when querying.
    items_raw = await db.query(
        container=ContainerType.INSIGHTS,
        filters={'user_id': user_id, 'insight_type': 'long_term_item'},
        order_by='-created_at',
    )

    result = []
    for item_data in items:
        try:
            result.append(LongTermInsightItem.from_dict(item_data))
        except Exception as exc:
            print(f'  Warning: Could not parse insight item: {exc}')
    return result


async def cleanup_demo_data(db: CosmosDBDatabase, user_id: str) -> None:
    items = await db.query(container=ContainerType.INSIGHTS, filters={'user_id': user_id})
    for item in items:
        await db.delete(container=ContainerType.INSIGHTS, document_id=item['id'], partition_key=user_id)
    print(f'[Cleaned up {len(items)} existing insights for demo user]')


async def prune_insights(
    db: CosmosDBDatabase,
    user_id: str,
    items: List[LongTermInsightItem],
    max_items: int,
    now: datetime,
) -> tuple[list[LongTermInsightItem], list[LongTermInsightItem]]:
    if len(items) <= max_items:
        return items, []

    ranked = rank_insights(items, now)
    kept = [item for item, _ in ranked[:max_items]]
    pruned = [item for item, _ in ranked[max_items:]]

    for item in pruned:
        await db.delete(container=ContainerType.INSIGHTS, document_id=item.id, partition_key=user_id)

    return kept, pruned


async def run_session_with_simulated_time(
    reflection: Reflection,
    db: CosmosDBDatabase,
    emb_provider: OpenAIEmbeddingProvider,
    user_id: str,
    session: Dict,
    simulated_now: datetime,
) -> Dict:
    from memory.prompts import SESSION_ANALYSIS_WITH_CITATIONS_PROMPT

    existing_items = await get_insight_items(db, user_id)
    existing_context = build_context_with_ids(existing_items)

    turns_text = '\n'.join([f"{role}: {content}" for role, content in session['turns']])
    full_context = f"{session['summary']}\n\nConversation:\n{turns_text}"

    prompt = SESSION_ANALYSIS_WITH_CITATIONS_PROMPT.format(
        existing_insights_context=existing_context,
        session_content=full_context,
    )

    try:
        analysis = reflection._call_llm_with_json(
            system_prompt='You are an expert session analysis assistant with memory tracking.',
            user_prompt=prompt,
            output_model=SessionAnalysisWithCitations,
        )
    except Exception as exc:
        print(f'  Error: {exc}')
        return {
            'session_summary': 'Error',
            'key_topics': [],
            'new_insights': [],
            'cited_insight_ids': [],
            'has_meaningful_content': False,
        }

    cited_ids = []
    for citation in analysis.cited_insights:
        cited_ids.append(citation.insight_id)
        doc = await db.get_by_id(
            container=ContainerType.INSIGHTS,
            document_id=citation.insight_id,
            partition_key=user_id,
        )
        if doc and doc.get('insight_type') == 'long_term_item':
            doc['access_count'] = doc.get('access_count', 0) + 1
            doc['last_accessed'] = simulated_now.isoformat()
            await db.upsert(container=ContainerType.INSIGHTS, document=doc, partition_key=user_id)

    id_gen = InsightIdGenerator([item.id for item in existing_items])
    new_insight_items = []

    for insight in analysis.new_insights:
        item = LongTermInsightItem(
            id=id_gen.next_id(),
            user_id=user_id,
            agent_id='default',
            insight_text=insight.insight_text,
            category=insight.category,
            confidence=insight.confidence,
            importance=insight.importance,
            date_added=simulated_now,
            last_accessed=simulated_now,
            access_count=0,
            source_session_ids=[session['session_id']],
        )
        new_insight_items.append(item)

    for item in new_insight_items:
        item.embedding = emb_provider.get_embedding(item.insight_text)
        await db.upsert(container=ContainerType.INSIGHTS, document=item.to_dict(), partition_key=user_id)

    return {
        'session_summary': analysis.session_summary,
        'key_topics': analysis.key_topics,
        'new_insights': [i.to_dict() for i in new_insight_items],
        'cited_insight_ids': cited_ids,
        'has_meaningful_content': analysis.has_meaningful_content,
    }


print('Helper functions are ready.')

# %% [markdown]
# ## Cell 3: Execute Full 6-Month Memory Simulation
#
# - Calls `run_demo()` to orchestrate all six monthly financial coaching sessions
# - Connects to CosmosDB and processes each session through LLM reflection system
# - Extracts new insights and ranks them by retention score (recency + frequency + importance)
# - Applies bounded-memory pruning when capacity exceeds MAX_INSIGHTS=5
# - Displays month-by-month evolution showing how insights decay/strengthen over time

# %%
async def run_demo() -> None:
    print_section('LONG-TERM MEMORY PRIORITIZATION DEMO (CosmosDB)')
    print(
        f"\nThis demo simulates 6 months of client sessions using Azure CosmosDB.\n\n"
        f"Key concepts demonstrated:\n"
        f"- RECENCY: New insights start with a grace-period boost\n"
        f"- FREQUENCY: Cited insights gain strength (access_count rises)\n"
        f"- FORGETTING: Old, uncited insights decay over time\n"
        f"- BOUNDED MEMORY: Only {MAX_INSIGHTS} insights are retained\n"
    )

    cosmos_endpoint = os.environ.get('COSMOS_ENDPOINT') or os.environ.get('AZURE_COSMOS_ENDPOINT')
    cosmos_key = os.environ.get('COSMOS_KEY') or os.environ.get('AZURE_COSMOS_KEY')

    if not cosmos_endpoint:
        raise ValueError('COSMOS_ENDPOINT/AZURE_COSMOS_ENDPOINT is required.')

    print('[Connecting to Azure CosmosDB...]')
    if cosmos_key:
        print('  Using key-based authentication')
        db = CosmosDBDatabase(
            endpoint=cosmos_endpoint,
            key=cosmos_key,
            database_name=os.environ.get('COSMOS_DATABASE', os.environ.get('AZURE_COSMOS_DATABASE_NAME', 'agent_memory_db')),
        )
    else:
        print('  No key found, trying Azure AD authentication...')
        from azure.identity import DefaultAzureCredential

        db = CosmosDBDatabase(
            endpoint=cosmos_endpoint,
            credential=DefaultAzureCredential(),
            database_name=os.environ.get('COSMOS_DATABASE', os.environ.get('AZURE_COSMOS_DATABASE_NAME', 'agent_memory_db')),
        )

    await db.initialize()
    print('[Connected successfully]')

    await cleanup_demo_data(db, USER_ID)

    emb_provider = OpenAIEmbeddingProvider(
        openai_client=client,
        model=os.environ.get('AZURE_OPENAI_EMB_DEPLOYMENT', 'text-embedding-ada-002'),
    )

    reflection = Reflection(
        agent_id='default',
        database=db,
        embedding_provider=emb_provider,
        chat_client=client,
        config=ReflectionConfig(
            PROCESSING_MODEL=(
                os.environ.get('AZURE_OPENAI_PROCESSING_MODEL')
                or os.environ.get('AZURE_OPENAI_REASONING_MODEL')
                or 'gpt-4o-mini'
            )
        ),
    )

    insight_history = []

    try:
        for month_idx, session in enumerate(TIMELINE, 1):
            simulated_now = session['simulated_date']
            print_section(f"SESSION {month_idx}: {session['title']}", '=')
            print(f"Simulated Date: {simulated_now.strftime('%B %d, %Y')}")

            items_before = await get_insight_items(db, USER_ID)
            if items_before:
                print_insight_table(items_before, simulated_now, 'Memory State BEFORE Session')
            else:
                print('\n[No existing insights - this is the first session]')

            print('\n[Processing session...]')
            result = await run_session_with_simulated_time(
                reflection, db, emb_provider, USER_ID, session, simulated_now
            )

            print(f"\nSummary: {result['session_summary'][:100]}...")
            print(f"New insights: {len(result['new_insights'])}")
            for ins in result['new_insights']:
                print(f"  - [{ins['id']}] {ins['insight_text'][:50]}...")

            if result['cited_insight_ids']:
                print(f"Cited existing: {result['cited_insight_ids']}")

            items_after = await get_insight_items(db, USER_ID)
            if len(items_after) > MAX_INSIGHTS:
                print(f"\nCapacity exceeded ({len(items_after)} > {MAX_INSIGHTS}). Pruning...")
                kept, pruned = await prune_insights(db, USER_ID, items_after, MAX_INSIGHTS, simulated_now)

                print('Forgotten:')
                for item in pruned:
                    score = calculate_retention_score(item, simulated_now)
                    age = (simulated_now - item.date_added).days
                    print(f"  - [{item.id}] score={score:.2f} age={age}d access={item.access_count}: {item.insight_text[:35]}...")

                print('Retained:')
                for item in kept:
                    score = calculate_retention_score(item, simulated_now)
                    age = (simulated_now - item.date_added).days
                    print(f"  - [{item.id}] score={score:.2f} age={age}d access={item.access_count}: {item.insight_text[:35]}...")

                items_after = kept

            print_insight_table(items_after, simulated_now, 'Memory State AFTER Session (Top 5)')

            insight_history.append({
                'month': month_idx,
                'date': simulated_now,
                'insights': [
                    (
                        i.id,
                        i.insight_text,
                        i.access_count,
                        calculate_retention_score(i, simulated_now),
                    )
                    for i in sorted(
                        items_after,
                        key=lambda x: calculate_retention_score(x, simulated_now),
                        reverse=True,
                    )
                ],
            })

        print_section('DEMO COMPLETE - MEMORY EVOLUTION SUMMARY', '=')
        print('\nHow insights evolved over 6 months (FULL TEXT):')
        print('-' * 120)
        for record in insight_history:
            print(f"\nMonth {record['month']} ({record['date'].strftime('%B %Y')}):")
            for insight_id, text, access, score in record['insights']:
                print(f"  [{insight_id}] score={score:.2f} access={access}")
                print(f"    ↳ {text[:110]}")

        print('\n' + '=' * 120)
        print('KEY OBSERVATIONS (CosmosDB):')
        print('=' * 120)
        print(
            'Same memory prioritization behavior as SQLite\n'
            'Scales with CosmosDB distribution and reliability\n'
            'Vector search supports semantic recall\n'
            'Bounded memory keeps the most relevant insights'
        )

    finally:
        await cleanup_demo_data(db, USER_ID)
        await db.close()
        print('\n[Demo data cleaned up]')


await run_demo()
# Out:
# ======================================================================
#  LONG-TERM MEMORY PRIORITIZATION DEMO (CosmosDB)
# ======================================================================
#
# This demo simulates 6 months of client sessions using Azure CosmosDB.
#
# Key concepts demonstrated:
# - RECENCY: New insights start with a grace-period boost
# - FREQUENCY: Cited insights gain strength (access_count rises)
# - FORGETTING: Old, uncited insights decay over time
# - BOUNDED MEMORY: Only 5 insights are retained
#
# [Connecting to Azure CosmosDB...]
#   Using key-based authentication
# [Connected successfully]
# [Cleaned up 42 existing insights for demo user]
#
# ======================================================================
#  SESSION 1: Month 1: Initial Consultation
# ======================================================================
# Simulated Date: January 15, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038   724.78       0    -186d       high  Alex has actually initiated their hous..
# INS-0022   721.08       0    -186d       high  Alex has started their house down paym..
# INS-0039   717.39       0    -186d       high  Alex has decided to increase their 401..
# INS-0029   713.69       0    -186d       high  Alex has committed to actually increas..
# INS-0030   702.59       0    -186d       high  Alex now explicitly describes their lo..
# INS-0023   702.59       0    -186d       high  Alex is willing to increase their 401k..
# INS-0021   702.59       0    -186d       high  Alex has explicitly adopted a barbell-..
# INS-0036   695.20       0    -186d       high  Alex has explicitly decided to increas..
# INS-0024   468.40       0    -186d     medium  Alex now understands and applies the c..
# INS-0019   228.31       0    -151d       high  Alex has a medium-term goal of saving ..
# INS-0017   227.16       0    -151d       high  Alex has successfully moved their Roth..
# INS-0018   224.85       0    -151d       high  Alex is now interested in opening a ta..
# INS-0035   219.08       0    -151d       high  Alex intends to use a taxable brokerag..
# INS-0020   219.08       0    -151d       high  Alex’s comfort with a target-date fund..
# INS-0034   214.47       0    -151d       high  Alex explicitly reports feeling good a..
# INS-0014    69.08       0    -115d       high  Alex recently received a promotion inc..
# INS-0016    68.38       0    -115d       high  Alex is specifically interested in tar..
# INS-0040    68.03       0    -115d       high  Alex explicitly describes target-date ..
# INS-0015    68.03       0    -115d       high  Alex is feeling more financially confi..
# INS-0037    66.98       0    -115d       high  Alex explicitly describes target-date ..
# INS-0042    66.29       0    -115d       high  Alex now explicitly describes themselv..
# INS-0041    66.29       0    -115d       high  Alex explicitly reports feeling good a..
# INS-0028    66.29       0    -115d       high  Alex explicitly connects their increas..
# INS-0033    64.89       0    -115d       high  Alex now explicitly describes themselv..
# INS-0012    14.79       0     -69d       high  Alex intends to remain in a money mark..
# INS-0025    14.64       0     -69d       high  Alex intends to max out their Roth IRA..
# INS-0010    14.33       0     -69d       high  Alex plans to max out their Roth IRA c..
# INS-0011     9.76       0     -69d     medium  Alex is on track with their short-term..
# INS-0013     9.66       0     -69d     medium  Alex correctly understands that Roth I..
# INS-0026     9.55       0     -69d     medium  Alex plans to stay in a money market f..
# INS-0027     9.35       0     -69d     medium  Alex’s confidence around investing is ..
# INS-0007     5.38       0     -36d       high  Alex chose a money market fund inside ..
# INS-0008     5.35       0     -36d       high  Alex explicitly states they cannot han..
# INS-0006     5.29       0     -36d       high  Alex opened a Roth IRA within the last..
# INS-0032     3.62       0     -36d     medium  Alex specifically needs to save about ..
# INS-0009     3.55       0     -36d     medium  Alex has a short-term financial goal t..
# INS-0003     1.93       0       0d       high  Alex prefers conservative, safe invest..
# INS-0002     1.93       0       0d       high  Alex is highly risk-averse due to thei..
# INS-0001     1.91       0       0d       high  Alex is a 28-year-old software enginee..
# INS-0031     1.90       0       0d       high  Alex explicitly identifies as being sc..
# INS-0004     1.90       0       0d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     1.88       0       0d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex, a 28-year-old software engineer earning $120k, discussed wanting to start investing but feelin...
# New insights: 0
# Cited existing: ['INS-0001', 'INS-0002', 'INS-0003', 'INS-0004', 'INS-0005', 'INS-0008']
#
# Capacity exceeded (42 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=702.59 age=-186d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=702.59 age=-186d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=695.20 age=-186d access=0: Alex has explicitly decided to incr...
#   - [INS-0024] score=468.40 age=-186d access=0: Alex now understands and applies th...
#   - [INS-0019] score=228.31 age=-151d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=227.16 age=-151d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=224.85 age=-151d access=0: Alex is now interested in opening a...
#   - [INS-0035] score=219.08 age=-151d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=219.08 age=-151d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=214.47 age=-151d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=69.08 age=-115d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=68.38 age=-115d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=68.03 age=-115d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=68.03 age=-115d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=66.98 age=-115d access=0: Alex explicitly describes target-da...
#   - [INS-0042] score=66.29 age=-115d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=66.29 age=-115d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=66.29 age=-115d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=64.89 age=-115d access=0: Alex now explicitly describes thems...
#   - [INS-0012] score=14.79 age=-69d access=0: Alex intends to remain in a money m...
#   - [INS-0025] score=14.64 age=-69d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=14.33 age=-69d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=9.76 age=-69d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=9.66 age=-69d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=9.55 age=-69d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=9.35 age=-69d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=5.38 age=-36d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=5.35 age=-36d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=5.29 age=-36d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0032] score=3.62 age=-36d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=3.55 age=-36d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=1.93 age=0d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=1.93 age=0d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=1.91 age=0d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=1.90 age=0d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=1.90 age=0d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=1.88 age=0d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=724.78 age=-186d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=721.08 age=-186d access=0: Alex has started their house down p...
#   - [INS-0039] score=717.39 age=-186d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=713.69 age=-186d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=702.59 age=-186d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038   724.78       0    -186d       high  Alex has actually initiated their hous..
# INS-0022   721.08       0    -186d       high  Alex has started their house down paym..
# INS-0039   717.39       0    -186d       high  Alex has decided to increase their 401..
# INS-0029   713.69       0    -186d       high  Alex has committed to actually increas..
# INS-0030   702.59       0    -186d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  SESSION 2: Month 2: Roth IRA Setup
# ======================================================================
# Simulated Date: February 20, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038   218.61       0    -150d       high  Alex has actually initiated their hous..
# INS-0022   217.49       0    -150d       high  Alex has started their house down paym..
# INS-0039   216.38       0    -150d       high  Alex has decided to increase their 401..
# INS-0029   215.26       0    -150d       high  Alex has committed to actually increas..
# INS-0030   211.92       0    -150d       high  Alex now explicitly describes their lo..
# INS-0023   211.92       0    -150d       high  Alex is willing to increase their 401k..
# INS-0021   211.92       0    -150d       high  Alex has explicitly adopted a barbell-..
# INS-0036   209.69       0    -150d       high  Alex has explicitly decided to increas..
# INS-0024   141.28       0    -150d     medium  Alex now understands and applies the c..
# INS-0019    69.08       0    -115d       high  Alex has a medium-term goal of saving ..
# INS-0017    68.73       0    -115d       high  Alex has successfully moved their Roth..
# INS-0018    68.03       0    -115d       high  Alex is now interested in opening a ta..
# INS-0035    66.29       0    -115d       high  Alex intends to use a taxable brokerag..
# INS-0020    66.29       0    -115d       high  Alex’s comfort with a target-date fund..
# INS-0034    64.89       0    -115d       high  Alex explicitly reports feeling good a..
# INS-0014    21.12       0     -79d       high  Alex recently received a promotion inc..
# INS-0016    20.90       0     -79d       high  Alex is specifically interested in tar..
# INS-0040    20.80       0     -79d       high  Alex explicitly describes target-date ..
# INS-0015    20.80       0     -79d       high  Alex is feeling more financially confi..
# INS-0037    20.48       0     -79d       high  Alex explicitly describes target-date ..
# INS-0042    20.26       0     -79d       high  Alex now explicitly describes themselv..
# INS-0041    20.26       0     -79d       high  Alex explicitly reports feeling good a..
# INS-0028    20.26       0     -79d       high  Alex explicitly connects their increas..
# INS-0033    19.84       0     -79d       high  Alex now explicitly describes themselv..
# INS-0012     4.76       0     -33d       high  Alex intends to remain in a money mark..
# INS-0025     4.71       0     -33d       high  Alex intends to max out their Roth IRA..
# INS-0010     4.61       0     -33d       high  Alex plans to max out their Roth IRA c..
# INS-0011     3.14       0     -33d     medium  Alex is on track with their short-term..
# INS-0013     3.11       0     -33d     medium  Alex correctly understands that Roth I..
# INS-0026     3.07       0     -33d     medium  Alex plans to stay in a money market f..
# INS-0027     3.01       0     -33d     medium  Alex’s confidence around investing is ..
# INS-0007     1.93       0       0d       high  Alex chose a money market fund inside ..
# INS-0008     1.92       0       0d       high  Alex explicitly states they cannot han..
# INS-0006     1.90       0       0d       high  Alex opened a Roth IRA within the last..
# INS-0032     1.30       0       0d     medium  Alex specifically needs to save about ..
# INS-0009     1.27       0       0d     medium  Alex has a short-term financial goal t..
# INS-0003     0.45       0    1m 6d       high  Alex prefers conservative, safe invest..
# INS-0002     0.45       0    1m 6d       high  Alex is highly risk-averse due to thei..
# INS-0001     0.44       0    1m 6d       high  Alex is a 28-year-old software enginee..
# INS-0031     0.44       0    1m 6d       high  Alex explicitly identifies as being sc..
# INS-0004     0.44       0    1m 6d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     0.44       0    1m 6d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex reported that they opened a Roth IRA and asked about the annual contribution limit. They shared...
# New insights: 1
#   - [INS-0043] Alex explicitly states they 'cannot handle volatil...
# Cited existing: ['INS-0007', 'INS-0008', 'INS-0009', 'INS-0010', 'INS-0005']
#
# Capacity exceeded (43 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=211.92 age=-150d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=211.92 age=-150d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=209.69 age=-150d access=0: Alex has explicitly decided to incr...
#   - [INS-0024] score=141.28 age=-150d access=0: Alex now understands and applies th...
#   - [INS-0019] score=69.08 age=-115d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=68.73 age=-115d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=68.03 age=-115d access=0: Alex is now interested in opening a...
#   - [INS-0035] score=66.29 age=-115d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=66.29 age=-115d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=64.89 age=-115d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=21.12 age=-79d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=20.90 age=-79d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=20.80 age=-79d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=20.80 age=-79d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=20.48 age=-79d access=0: Alex explicitly describes target-da...
#   - [INS-0042] score=20.26 age=-79d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=20.26 age=-79d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=20.26 age=-79d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=19.84 age=-79d access=0: Alex now explicitly describes thems...
#   - [INS-0012] score=4.76 age=-33d access=0: Alex intends to remain in a money m...
#   - [INS-0025] score=4.71 age=-33d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=4.61 age=-33d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=3.14 age=-33d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=3.11 age=-33d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=3.07 age=-33d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=3.01 age=-33d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=1.93 age=0d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=1.92 age=0d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=1.90 age=0d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0043] score=1.85 age=0d access=0: Alex explicitly states they 'cannot...
#   - [INS-0032] score=1.30 age=0d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=1.27 age=0d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=0.45 age=36d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=0.45 age=36d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=0.44 age=36d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=0.44 age=36d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=0.44 age=36d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=0.44 age=36d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=218.61 age=-150d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=217.49 age=-150d access=0: Alex has started their house down p...
#   - [INS-0039] score=216.38 age=-150d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=215.26 age=-150d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=211.92 age=-150d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038   218.61       0    -150d       high  Alex has actually initiated their hous..
# INS-0022   217.49       0    -150d       high  Alex has started their house down paym..
# INS-0039   216.38       0    -150d       high  Alex has decided to increase their 401..
# INS-0029   215.26       0    -150d       high  Alex has committed to actually increas..
# INS-0030   211.92       0    -150d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  SESSION 3: Month 3: Tax Season Questions
# ======================================================================
# Simulated Date: March 25, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038    73.06       0    -117d       high  Alex has actually initiated their hous..
# INS-0022    72.69       0    -117d       high  Alex has started their house down paym..
# INS-0039    72.32       0    -117d       high  Alex has decided to increase their 401..
# INS-0029    71.94       0    -117d       high  Alex has committed to actually increas..
# INS-0030    70.83       0    -117d       high  Alex now explicitly describes their lo..
# INS-0023    70.83       0    -117d       high  Alex is willing to increase their 401k..
# INS-0021    70.83       0    -117d       high  Alex has explicitly adopted a barbell-..
# INS-0036    70.08       0    -117d       high  Alex has explicitly decided to increas..
# INS-0024    47.22       0    -117d     medium  Alex now understands and applies the c..
# INS-0019    23.29       0     -82d       high  Alex has a medium-term goal of saving ..
# INS-0017    23.17       0     -82d       high  Alex has successfully moved their Roth..
# INS-0018    22.94       0     -82d       high  Alex is now interested in opening a ta..
# INS-0035    22.35       0     -82d       high  Alex intends to use a taxable brokerag..
# INS-0020    22.35       0     -82d       high  Alex’s comfort with a target-date fund..
# INS-0034    21.88       0     -82d       high  Alex explicitly reports feeling good a..
# INS-0014     7.33       0     -46d       high  Alex recently received a promotion inc..
# INS-0016     7.25       0     -46d       high  Alex is specifically interested in tar..
# INS-0040     7.22       0     -46d       high  Alex explicitly describes target-date ..
# INS-0015     7.22       0     -46d       high  Alex is feeling more financially confi..
# INS-0037     7.10       0     -46d       high  Alex explicitly describes target-date ..
# INS-0042     7.03       0     -46d       high  Alex now explicitly describes themselv..
# INS-0041     7.03       0     -46d       high  Alex explicitly reports feeling good a..
# INS-0028     7.03       0     -46d       high  Alex explicitly connects their increas..
# INS-0033     6.88       0     -46d       high  Alex now explicitly describes themselv..
# INS-0012     1.87       0       0d       high  Alex intends to remain in a money mark..
# INS-0025     1.85       0       0d       high  Alex intends to max out their Roth IRA..
# INS-0010     1.81       0       0d       high  Alex plans to max out their Roth IRA c..
# INS-0011     1.23       0       0d     medium  Alex is on track with their short-term..
# INS-0013     1.22       0       0d     medium  Alex correctly understands that Roth I..
# INS-0026     1.21       0       0d     medium  Alex plans to stay in a money market f..
# INS-0027     1.18       0       0d     medium  Alex’s confidence around investing is ..
# INS-0007     0.49       0    1m 3d       high  Alex chose a money market fund inside ..
# INS-0008     0.49       0    1m 3d       high  Alex explicitly states they cannot han..
# INS-0006     0.49       0    1m 3d       high  Alex opened a Roth IRA within the last..
# INS-0043     0.47       0    1m 3d       high  Alex explicitly states they 'cannot ha..
# INS-0032     0.33       0    1m 3d     medium  Alex specifically needs to save about ..
# INS-0009     0.33       0    1m 3d     medium  Alex has a short-term financial goal t..
# INS-0003     0.15       0    2m 9d       high  Alex prefers conservative, safe invest..
# INS-0002     0.15       0    2m 9d       high  Alex is highly risk-averse due to thei..
# INS-0001     0.15       0    2m 9d       high  Alex is a 28-year-old software enginee..
# INS-0031     0.15       0    2m 9d       high  Alex explicitly identifies as being sc..
# INS-0004     0.15       0    2m 9d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     0.15       0    2m 9d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex asked whether Roth IRA contributions reduce their taxable income and was reminded that Roth con...
# New insights: 2
#   - [INS-0044] Alex explicitly plans to max out their Roth IRA co...
#   - [INS-0045] Alex intends to remain in money market holdings wi...
# Cited existing: ['INS-0013', 'INS-0010', 'INS-0012', 'INS-0007', 'INS-0003']
#
# Capacity exceeded (45 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=70.83 age=-117d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=70.83 age=-117d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=70.08 age=-117d access=0: Alex has explicitly decided to incr...
#   - [INS-0024] score=47.22 age=-117d access=0: Alex now understands and applies th...
#   - [INS-0019] score=23.29 age=-82d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=23.17 age=-82d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=22.94 age=-82d access=0: Alex is now interested in opening a...
#   - [INS-0035] score=22.35 age=-82d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=22.35 age=-82d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=21.88 age=-82d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=7.33 age=-46d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=7.25 age=-46d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=7.22 age=-46d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=7.22 age=-46d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=7.10 age=-46d access=0: Alex explicitly describes target-da...
#   - [INS-0042] score=7.03 age=-46d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=7.03 age=-46d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=7.03 age=-46d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=6.88 age=-46d access=0: Alex now explicitly describes thems...
#   - [INS-0044] score=1.90 age=0d access=0: Alex explicitly plans to max out th...
#   - [INS-0012] score=1.87 age=0d access=0: Alex intends to remain in a money m...
#   - [INS-0045] score=1.85 age=0d access=0: Alex intends to remain in money mar...
#   - [INS-0025] score=1.85 age=0d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=1.81 age=0d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=1.23 age=0d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=1.22 age=0d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=1.21 age=0d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=1.18 age=0d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=0.49 age=33d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=0.49 age=33d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=0.49 age=33d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0043] score=0.47 age=33d access=0: Alex explicitly states they 'cannot...
#   - [INS-0032] score=0.33 age=33d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=0.33 age=33d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=0.15 age=69d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=0.15 age=69d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=0.15 age=69d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=0.15 age=69d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=0.15 age=69d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=0.15 age=69d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=73.06 age=-117d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=72.69 age=-117d access=0: Alex has started their house down p...
#   - [INS-0039] score=72.32 age=-117d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=71.94 age=-117d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=70.83 age=-117d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038    73.06       0    -117d       high  Alex has actually initiated their hous..
# INS-0022    72.69       0    -117d       high  Alex has started their house down paym..
# INS-0039    72.32       0    -117d       high  Alex has decided to increase their 401..
# INS-0029    71.94       0    -117d       high  Alex has committed to actually increas..
# INS-0030    70.83       0    -117d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  SESSION 4: Month 4: Post-Wedding, Promotion News
# ======================================================================
# Simulated Date: May 10, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038    16.11       0     -71d       high  Alex has actually initiated their hous..
# INS-0022    16.03       0     -71d       high  Alex has started their house down paym..
# INS-0039    15.95       0     -71d       high  Alex has decided to increase their 401..
# INS-0029    15.87       0     -71d       high  Alex has committed to actually increas..
# INS-0030    15.62       0     -71d       high  Alex now explicitly describes their lo..
# INS-0023    15.62       0     -71d       high  Alex is willing to increase their 401k..
# INS-0021    15.62       0     -71d       high  Alex has explicitly adopted a barbell-..
# INS-0036    15.46       0     -71d       high  Alex has explicitly decided to increas..
# INS-0024    10.41       0     -71d     medium  Alex now understands and applies the c..
# INS-0019     5.38       0     -36d       high  Alex has a medium-term goal of saving ..
# INS-0017     5.35       0     -36d       high  Alex has successfully moved their Roth..
# INS-0018     5.29       0     -36d       high  Alex is now interested in opening a ta..
# INS-0035     5.16       0     -36d       high  Alex intends to use a taxable brokerag..
# INS-0020     5.16       0     -36d       high  Alex’s comfort with a target-date fund..
# INS-0034     5.05       0     -36d       high  Alex explicitly reports feeling good a..
# INS-0014     1.93       0       0d       high  Alex recently received a promotion inc..
# INS-0016     1.91       0       0d       high  Alex is specifically interested in tar..
# INS-0040     1.90       0       0d       high  Alex explicitly describes target-date ..
# INS-0015     1.90       0       0d       high  Alex is feeling more financially confi..
# INS-0037     1.87       0       0d       high  Alex explicitly describes target-date ..
# INS-0042     1.85       0       0d       high  Alex now explicitly describes themselv..
# INS-0041     1.85       0       0d       high  Alex explicitly reports feeling good a..
# INS-0028     1.85       0       0d       high  Alex explicitly connects their increas..
# INS-0033     1.81       0       0d       high  Alex now explicitly describes themselv..
# INS-0044     0.32       0   1m 16d       high  Alex explicitly plans to max out their..
# INS-0012     0.31       0   1m 16d       high  Alex intends to remain in a money mark..
# INS-0045     0.31       0   1m 16d       high  Alex intends to remain in money market..
# INS-0025     0.31       0   1m 16d       high  Alex intends to max out their Roth IRA..
# INS-0010     0.30       0   1m 16d       high  Alex plans to max out their Roth IRA c..
# INS-0011     0.21       0   1m 16d     medium  Alex is on track with their short-term..
# INS-0013     0.20       0   1m 16d     medium  Alex correctly understands that Roth I..
# INS-0026     0.20       0   1m 16d     medium  Alex plans to stay in a money market f..
# INS-0027     0.20       0   1m 16d     medium  Alex’s confidence around investing is ..
# INS-0007     0.11       0   2m 19d       high  Alex chose a money market fund inside ..
# INS-0008     0.11       0   2m 19d       high  Alex explicitly states they cannot han..
# INS-0006     0.11       0   2m 19d       high  Alex opened a Roth IRA within the last..
# INS-0043     0.10       0   2m 19d       high  Alex explicitly states they 'cannot ha..
# INS-0032     0.07       0   2m 19d     medium  Alex specifically needs to save about ..
# INS-0009     0.07       0   2m 19d     medium  Alex has a short-term financial goal t..
# INS-0003     0.03       0   3m 25d       high  Alex prefers conservative, safe invest..
# INS-0002     0.03       0   3m 25d       high  Alex is highly risk-averse due to thei..
# INS-0001     0.03       0   3m 25d       high  Alex is a 28-year-old software enginee..
# INS-0031     0.03       0   3m 25d       high  Alex explicitly identifies as being sc..
# INS-0004     0.03       0   3m 25d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     0.03       0   3m 25d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex reported that their sister’s wedding went well and that they received a promotion to a $150k in...
# New insights: 2
#   - [INS-0046] Alex explicitly states that they now feel more con...
#   - [INS-0047] Alex now views target-date funds specifically as a...
# Cited existing: ['INS-0014', 'INS-0033', 'INS-0016', 'INS-0020', 'INS-0041']
#
# Capacity exceeded (47 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=15.62 age=-71d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=15.62 age=-71d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=15.46 age=-71d access=0: Alex has explicitly decided to incr...
#   - [INS-0024] score=10.41 age=-71d access=0: Alex now understands and applies th...
#   - [INS-0019] score=5.38 age=-36d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=5.35 age=-36d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=5.29 age=-36d access=0: Alex is now interested in opening a...
#   - [INS-0035] score=5.16 age=-36d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=5.16 age=-36d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=5.05 age=-36d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=1.93 age=0d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=1.91 age=0d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=1.90 age=0d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=1.90 age=0d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=1.87 age=0d access=0: Alex explicitly describes target-da...
#   - [INS-0047] score=1.85 age=0d access=0: Alex now views target-date funds sp...
#   - [INS-0046] score=1.85 age=0d access=0: Alex explicitly states that they no...
#   - [INS-0042] score=1.85 age=0d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=1.85 age=0d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=1.85 age=0d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=1.81 age=0d access=0: Alex now explicitly describes thems...
#   - [INS-0044] score=0.32 age=46d access=0: Alex explicitly plans to max out th...
#   - [INS-0012] score=0.31 age=46d access=0: Alex intends to remain in a money m...
#   - [INS-0045] score=0.31 age=46d access=0: Alex intends to remain in money mar...
#   - [INS-0025] score=0.31 age=46d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=0.30 age=46d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=0.21 age=46d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=0.20 age=46d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=0.20 age=46d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=0.20 age=46d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=0.11 age=79d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=0.11 age=79d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=0.11 age=79d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0043] score=0.10 age=79d access=0: Alex explicitly states they 'cannot...
#   - [INS-0032] score=0.07 age=79d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=0.07 age=79d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=0.03 age=115d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=0.03 age=115d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=0.03 age=115d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=0.03 age=115d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=0.03 age=115d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=0.03 age=115d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=16.11 age=-71d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=16.03 age=-71d access=0: Alex has started their house down p...
#   - [INS-0039] score=15.95 age=-71d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=15.87 age=-71d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=15.62 age=-71d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038    16.11       0     -71d       high  Alex has actually initiated their hous..
# INS-0022    16.03       0     -71d       high  Alex has started their house down paym..
# INS-0039    15.95       0     -71d       high  Alex has decided to increase their 401..
# INS-0029    15.87       0     -71d       high  Alex has committed to actually increas..
# INS-0030    15.62       0     -71d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  SESSION 5: Month 5: Risk Tolerance Shift
# ======================================================================
# Simulated Date: June 15, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038     5.16       0     -35d       high  Alex has actually initiated their hous..
# INS-0022     5.14       0     -35d       high  Alex has started their house down paym..
# INS-0039     5.11       0     -35d       high  Alex has decided to increase their 401..
# INS-0029     5.08       0     -35d       high  Alex has committed to actually increas..
# INS-0030     5.00       0     -35d       high  Alex now explicitly describes their lo..
# INS-0023     5.00       0     -35d       high  Alex is willing to increase their 401k..
# INS-0021     5.00       0     -35d       high  Alex has explicitly adopted a barbell-..
# INS-0036     4.95       0     -35d       high  Alex has explicitly decided to increas..
# INS-0024     3.34       0     -35d     medium  Alex now understands and applies the c..
# INS-0019     1.93       0       0d       high  Alex has a medium-term goal of saving ..
# INS-0017     1.92       0       0d       high  Alex has successfully moved their Roth..
# INS-0018     1.90       0       0d       high  Alex is now interested in opening a ta..
# INS-0035     1.85       0       0d       high  Alex intends to use a taxable brokerag..
# INS-0020     1.85       0       0d       high  Alex’s comfort with a target-date fund..
# INS-0034     1.81       0       0d       high  Alex explicitly reports feeling good a..
# INS-0014     0.45       0    1m 6d       high  Alex recently received a promotion inc..
# INS-0016     0.44       0    1m 6d       high  Alex is specifically interested in tar..
# INS-0040     0.44       0    1m 6d       high  Alex explicitly describes target-date ..
# INS-0015     0.44       0    1m 6d       high  Alex is feeling more financially confi..
# INS-0037     0.43       0    1m 6d       high  Alex explicitly describes target-date ..
# INS-0047     0.43       0    1m 6d       high  Alex now views target-date funds speci..
# INS-0046     0.43       0    1m 6d       high  Alex explicitly states that they now f..
# INS-0042     0.43       0    1m 6d       high  Alex now explicitly describes themselv..
# INS-0041     0.43       0    1m 6d       high  Alex explicitly reports feeling good a..
# INS-0028     0.43       0    1m 6d       high  Alex explicitly connects their increas..
# INS-0033     0.42       0    1m 6d       high  Alex now explicitly describes themselv..
# INS-0044     0.10       0   2m 22d       high  Alex explicitly plans to max out their..
# INS-0012     0.09       0   2m 22d       high  Alex intends to remain in a money mark..
# INS-0045     0.09       0   2m 22d       high  Alex intends to remain in money market..
# INS-0025     0.09       0   2m 22d       high  Alex intends to max out their Roth IRA..
# INS-0010     0.09       0   2m 22d       high  Alex plans to max out their Roth IRA c..
# INS-0011     0.06       0   2m 22d     medium  Alex is on track with their short-term..
# INS-0013     0.06       0   2m 22d     medium  Alex correctly understands that Roth I..
# INS-0026     0.06       0   2m 22d     medium  Alex plans to stay in a money market f..
# INS-0027     0.06       0   2m 22d     medium  Alex’s confidence around investing is ..
# INS-0007     0.03       0   3m 25d       high  Alex chose a money market fund inside ..
# INS-0008     0.03       0   3m 25d       high  Alex explicitly states they cannot han..
# INS-0006     0.03       0   3m 25d       high  Alex opened a Roth IRA within the last..
# INS-0043     0.03       0   3m 25d       high  Alex explicitly states they 'cannot ha..
# INS-0032     0.02       0   3m 25d     medium  Alex specifically needs to save about ..
# INS-0009     0.02       0   3m 25d     medium  Alex has a short-term financial goal t..
# INS-0003     0.01       0    5m 1d       high  Alex prefers conservative, safe invest..
# INS-0002     0.01       0    5m 1d       high  Alex is highly risk-averse due to thei..
# INS-0001     0.01       0    5m 1d       high  Alex is a 28-year-old software enginee..
# INS-0031     0.01       0    5m 1d       high  Alex explicitly identifies as being sc..
# INS-0004     0.01       0    5m 1d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     0.01       0    5m 1d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex reported moving their Roth IRA into a 2060 target-date fund and expressed feeling good about th...
# New insights: 1
#   - [INS-0048] Alex has now concretely linked their taxable broke...
# Cited existing: ['INS-0017', 'INS-0034', 'INS-0041', 'INS-0019', 'INS-0035', 'INS-0018', 'INS-0024']
#
# Capacity exceeded (48 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=5.00 age=-35d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=5.00 age=-35d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=4.95 age=-35d access=0: Alex has explicitly decided to incr...
#   - [INS-0024] score=3.34 age=-35d access=0: Alex now understands and applies th...
#   - [INS-0019] score=1.93 age=0d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=1.92 age=0d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=1.90 age=0d access=0: Alex is now interested in opening a...
#   - [INS-0048] score=1.85 age=0d access=0: Alex has now concretely linked thei...
#   - [INS-0035] score=1.85 age=0d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=1.85 age=0d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=1.81 age=0d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=0.45 age=36d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=0.44 age=36d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=0.44 age=36d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=0.44 age=36d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=0.43 age=36d access=0: Alex explicitly describes target-da...
#   - [INS-0047] score=0.43 age=36d access=0: Alex now views target-date funds sp...
#   - [INS-0046] score=0.43 age=36d access=0: Alex explicitly states that they no...
#   - [INS-0042] score=0.43 age=36d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=0.43 age=36d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=0.43 age=36d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=0.42 age=36d access=0: Alex now explicitly describes thems...
#   - [INS-0044] score=0.10 age=82d access=0: Alex explicitly plans to max out th...
#   - [INS-0012] score=0.09 age=82d access=0: Alex intends to remain in a money m...
#   - [INS-0045] score=0.09 age=82d access=0: Alex intends to remain in money mar...
#   - [INS-0025] score=0.09 age=82d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=0.09 age=82d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=0.06 age=82d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=0.06 age=82d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=0.06 age=82d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=0.06 age=82d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=0.03 age=115d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=0.03 age=115d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=0.03 age=115d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0043] score=0.03 age=115d access=0: Alex explicitly states they 'cannot...
#   - [INS-0032] score=0.02 age=115d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=0.02 age=115d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=0.01 age=151d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=0.01 age=151d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=0.01 age=151d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=0.01 age=151d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=0.01 age=151d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=0.01 age=151d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=5.16 age=-35d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=5.14 age=-35d access=0: Alex has started their house down p...
#   - [INS-0039] score=5.11 age=-35d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=5.08 age=-35d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=5.00 age=-35d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038     5.16       0     -35d       high  Alex has actually initiated their hous..
# INS-0022     5.14       0     -35d       high  Alex has started their house down paym..
# INS-0039     5.11       0     -35d       high  Alex has decided to increase their 401..
# INS-0029     5.08       0     -35d       high  Alex has committed to actually increas..
# INS-0030     5.00       0     -35d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  SESSION 6: Month 6: Current State & Planning
# ======================================================================
# Simulated Date: July 20, 2025
#
# Memory State BEFORE Session:
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038     1.91       0       0d       high  Alex has actually initiated their hous..
# INS-0022     1.90       0       0d       high  Alex has started their house down paym..
# INS-0039     1.89       0       0d       high  Alex has decided to increase their 401..
# INS-0029     1.88       0       0d       high  Alex has committed to actually increas..
# INS-0030     1.85       0       0d       high  Alex now explicitly describes their lo..
# INS-0023     1.85       0       0d       high  Alex is willing to increase their 401k..
# INS-0021     1.85       0       0d       high  Alex has explicitly adopted a barbell-..
# INS-0036     1.83       0       0d       high  Alex has explicitly decided to increas..
# INS-0024     1.23       0       0d     medium  Alex now understands and applies the c..
# INS-0019     0.46       0    1m 5d       high  Alex has a medium-term goal of saving ..
# INS-0017     0.46       0    1m 5d       high  Alex has successfully moved their Roth..
# INS-0018     0.46       0    1m 5d       high  Alex is now interested in opening a ta..
# INS-0048     0.44       0    1m 5d       high  Alex has now concretely linked their t..
# INS-0035     0.44       0    1m 5d       high  Alex intends to use a taxable brokerag..
# INS-0020     0.44       0    1m 5d       high  Alex’s comfort with a target-date fund..
# INS-0034     0.43       0    1m 5d       high  Alex explicitly reports feeling good a..
# INS-0014     0.14       0   2m 11d       high  Alex recently received a promotion inc..
# INS-0016     0.14       0   2m 11d       high  Alex is specifically interested in tar..
# INS-0040     0.14       0   2m 11d       high  Alex explicitly describes target-date ..
# INS-0015     0.14       0   2m 11d       high  Alex is feeling more financially confi..
# INS-0037     0.14       0   2m 11d       high  Alex explicitly describes target-date ..
# INS-0047     0.13       0   2m 11d       high  Alex now views target-date funds speci..
# INS-0046     0.13       0   2m 11d       high  Alex explicitly states that they now f..
# INS-0042     0.13       0   2m 11d       high  Alex now explicitly describes themselv..
# INS-0041     0.13       0   2m 11d       high  Alex explicitly reports feeling good a..
# INS-0028     0.13       0   2m 11d       high  Alex explicitly connects their increas..
# INS-0033     0.13       0   2m 11d       high  Alex now explicitly describes themselv..
# INS-0044     0.03       0   3m 27d       high  Alex explicitly plans to max out their..
# INS-0012     0.03       0   3m 27d       high  Alex intends to remain in a money mark..
# INS-0045     0.03       0   3m 27d       high  Alex intends to remain in money market..
# INS-0025     0.03       0   3m 27d       high  Alex intends to max out their Roth IRA..
# INS-0010     0.03       0   3m 27d       high  Alex plans to max out their Roth IRA c..
# INS-0011     0.02       0   3m 27d     medium  Alex is on track with their short-term..
# INS-0013     0.02       0   3m 27d     medium  Alex correctly understands that Roth I..
# INS-0026     0.02       0   3m 27d     medium  Alex plans to stay in a money market f..
# INS-0027     0.02       0   3m 27d     medium  Alex’s confidence around investing is ..
# INS-0007     0.01       0    5m 0d       high  Alex chose a money market fund inside ..
# INS-0008     0.01       0    5m 0d       high  Alex explicitly states they cannot han..
# INS-0006     0.01       0    5m 0d       high  Alex opened a Roth IRA within the last..
# INS-0043     0.01       0    5m 0d       high  Alex explicitly states they 'cannot ha..
# INS-0032     0.01       0    5m 0d     medium  Alex specifically needs to save about ..
# INS-0009     0.01       0    5m 0d     medium  Alex has a short-term financial goal t..
# INS-0003     0.00       0    6m 6d       high  Alex prefers conservative, safe invest..
# INS-0002     0.00       0    6m 6d       high  Alex is highly risk-averse due to thei..
# INS-0001     0.00       0    6m 6d       high  Alex is a 28-year-old software enginee..
# INS-0031     0.00       0    6m 6d       high  Alex explicitly identifies as being sc..
# INS-0004     0.00       0    6m 6d       high  Alex has a $10,000 emergency fund set ..
# INS-0005     0.00       0    6m 6d       high  Alex is interested in learning about R..
# -----------------------------------------------------------------------------------------------
#
# [Processing session...]
#
# Summary: Alex reported starting their house down payment fund with $5,000 invested conservatively. They then ...
# New insights: 1
#   - [INS-0049] Alex follows through quickly on retirement savings...
# Cited existing: ['INS-0038', 'INS-0022', 'INS-0021', 'INS-0039', 'INS-0036', 'INS-0029', 'INS-0014', 'INS-0024']
#
# Capacity exceeded (49 > 5). Pruning...
# Forgotten:
#   - [INS-0023] score=1.85 age=0d access=0: Alex is willing to increase their 4...
#   - [INS-0021] score=1.85 age=0d access=0: Alex has explicitly adopted a barbe...
#   - [INS-0036] score=1.83 age=0d access=0: Alex has explicitly decided to incr...
#   - [INS-0049] score=1.81 age=0d access=0: Alex follows through quickly on ret...
#   - [INS-0024] score=1.23 age=0d access=0: Alex now understands and applies th...
#   - [INS-0019] score=0.46 age=35d access=0: Alex has a medium-term goal of savi...
#   - [INS-0017] score=0.46 age=35d access=0: Alex has successfully moved their R...
#   - [INS-0018] score=0.46 age=35d access=0: Alex is now interested in opening a...
#   - [INS-0048] score=0.44 age=35d access=0: Alex has now concretely linked thei...
#   - [INS-0035] score=0.44 age=35d access=0: Alex intends to use a taxable broke...
#   - [INS-0020] score=0.44 age=35d access=0: Alex’s comfort with a target-date f...
#   - [INS-0034] score=0.43 age=35d access=0: Alex explicitly reports feeling goo...
#   - [INS-0014] score=0.14 age=71d access=0: Alex recently received a promotion ...
#   - [INS-0016] score=0.14 age=71d access=0: Alex is specifically interested in ...
#   - [INS-0040] score=0.14 age=71d access=0: Alex explicitly describes target-da...
#   - [INS-0015] score=0.14 age=71d access=0: Alex is feeling more financially co...
#   - [INS-0037] score=0.14 age=71d access=0: Alex explicitly describes target-da...
#   - [INS-0047] score=0.13 age=71d access=0: Alex now views target-date funds sp...
#   - [INS-0046] score=0.13 age=71d access=0: Alex explicitly states that they no...
#   - [INS-0042] score=0.13 age=71d access=0: Alex now explicitly describes thems...
#   - [INS-0041] score=0.13 age=71d access=0: Alex explicitly reports feeling goo...
#   - [INS-0028] score=0.13 age=71d access=0: Alex explicitly connects their incr...
#   - [INS-0033] score=0.13 age=71d access=0: Alex now explicitly describes thems...
#   - [INS-0044] score=0.03 age=117d access=0: Alex explicitly plans to max out th...
#   - [INS-0012] score=0.03 age=117d access=0: Alex intends to remain in a money m...
#   - [INS-0045] score=0.03 age=117d access=0: Alex intends to remain in money mar...
#   - [INS-0025] score=0.03 age=117d access=0: Alex intends to max out their Roth ...
#   - [INS-0010] score=0.03 age=117d access=0: Alex plans to max out their Roth IR...
#   - [INS-0011] score=0.02 age=117d access=0: Alex is on track with their short-t...
#   - [INS-0013] score=0.02 age=117d access=0: Alex correctly understands that Rot...
#   - [INS-0026] score=0.02 age=117d access=0: Alex plans to stay in a money marke...
#   - [INS-0027] score=0.02 age=117d access=0: Alex’s confidence around investing ...
#   - [INS-0007] score=0.01 age=150d access=0: Alex chose a money market fund insi...
#   - [INS-0008] score=0.01 age=150d access=0: Alex explicitly states they cannot ...
#   - [INS-0006] score=0.01 age=150d access=0: Alex opened a Roth IRA within the l...
#   - [INS-0043] score=0.01 age=150d access=0: Alex explicitly states they 'cannot...
#   - [INS-0032] score=0.01 age=150d access=0: Alex specifically needs to save abo...
#   - [INS-0009] score=0.01 age=150d access=0: Alex has a short-term financial goa...
#   - [INS-0003] score=0.00 age=186d access=0: Alex prefers conservative, safe inv...
#   - [INS-0002] score=0.00 age=186d access=0: Alex is highly risk-averse due to t...
#   - [INS-0001] score=0.00 age=186d access=0: Alex is a 28-year-old software engi...
#   - [INS-0031] score=0.00 age=186d access=0: Alex explicitly identifies as being...
#   - [INS-0004] score=0.00 age=186d access=0: Alex has a $10,000 emergency fund s...
#   - [INS-0005] score=0.00 age=186d access=0: Alex is interested in learning abou...
# Retained:
#   - [INS-0038] score=1.91 age=0d access=0: Alex has actually initiated their h...
#   - [INS-0022] score=1.90 age=0d access=0: Alex has started their house down p...
#   - [INS-0039] score=1.89 age=0d access=0: Alex has decided to increase their ...
#   - [INS-0029] score=1.88 age=0d access=0: Alex has committed to actually incr...
#   - [INS-0030] score=1.85 age=0d access=0: Alex now explicitly describes their...
#
# Memory State AFTER Session (Top 5):
# -----------------------------------------------------------------------------------------------
# ID          Score  Access      Age Importance  Text
# -----------------------------------------------------------------------------------------------
# INS-0038     1.91       0       0d       high  Alex has actually initiated their hous..
# INS-0022     1.90       0       0d       high  Alex has started their house down paym..
# INS-0039     1.89       0       0d       high  Alex has decided to increase their 401..
# INS-0029     1.88       0       0d       high  Alex has committed to actually increas..
# INS-0030     1.85       0       0d       high  Alex now explicitly describes their lo..
# -----------------------------------------------------------------------------------------------
#
# ======================================================================
#  DEMO COMPLETE - MEMORY EVOLUTION SUMMARY
# ======================================================================
#
# How insights evolved over 6 months (FULL TEXT):
# ------------------------------------------------------------------------------------------------------------------------
#
# Month 1 (January 2025):
#   [INS-0038] score=724.78 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=721.08 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=717.39 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=713.69 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=702.59 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# Month 2 (February 2025):
#   [INS-0038] score=218.61 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=217.49 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=216.38 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=215.26 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=211.92 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# Month 3 (March 2025):
#   [INS-0038] score=73.06 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=72.69 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=72.32 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=71.94 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=70.83 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# Month 4 (May 2025):
#   [INS-0038] score=16.11 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=16.03 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=15.95 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=15.87 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=15.62 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# Month 5 (June 2025):
#   [INS-0038] score=5.16 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=5.14 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=5.11 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=5.08 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=5.00 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# Month 6 (July 2025):
#   [INS-0038] score=1.91 access=0
#     ↳ Alex has actually initiated their house fund with a $5,000 contribution and kept it conservatively invested, c
#   [INS-0022] score=1.90 access=0
#     ↳ Alex has started their house down payment fund with an initial $5,000 contribution and intends to keep that po
#   [INS-0039] score=1.89 access=0
#     ↳ Alex has decided to increase their 401k contributions now in response to advice that maxing out at their $150k
#   [INS-0029] score=1.88 access=0
#     ↳ Alex has committed to actually increasing their 401k contributions to the annual maximum after confirming it f
#   [INS-0030] score=1.85 access=0
#     ↳ Alex now explicitly describes their long-term retirement investments as aggressive and their house fund as con
#
# ========================================================================================================================
# KEY OBSERVATIONS (CosmosDB):
# ========================================================================================================================
# Same memory prioritization behavior as SQLite
# Scales with CosmosDB distribution and reliability
# Vector search supports semantic recall
# Bounded memory keeps the most relevant insights
# [Cleaned up 49 existing insights for demo user]
#
# [Demo data cleaned up]
